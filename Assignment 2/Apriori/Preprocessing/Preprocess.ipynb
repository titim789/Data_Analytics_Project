# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv("train.csv")

# %%
data = data.drop(['music','hq','fullscreen'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26296946 entries, 0 to 26296945
# Data columns (total 17 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   session_id      int64
#  1   index           int64
#  2   elapsed_time    int64
#  3   event_name      object
#  4   name            object
#  5   level           int64
#  6   page            float64
#  7   room_coor_x     float64
#  8   room_coor_y     float64
#  9   screen_coor_x   float64
#  10  screen_coor_y   float64
#  11  hover_duration  float64
#  12  text            object
#  13  fqid            object
#  14  room_fqid       object
#  15  text_fqid       object
#  16  level_group     object
# dtypes: float64(6), int64(4), object(7)
# memory usage: 3.3+ GB

# %%
data
# Out:
#                  session_id  index  elapsed_time      event_name       name  \
# 0         20090312431273200      0             0  cutscene_click      basic
# 1         20090312431273200      1          1323    person_click      basic
# 2         20090312431273200      2           831    person_click      basic
# 3         20090312431273200      3          1147    person_click      basic
# 4         20090312431273200      4          1863    person_click      basic
# ...                     ...    ...           ...             ...        ...
# 26296941  22100221145014656   1600       5483231  navigate_click  undefined
# 26296942  22100221145014656   1601       5485166  navigate_click  undefined
# 26296943  22100221145014656   1602       5485917  navigate_click  undefined
# 26296944  22100221145014656   1603       5486753  navigate_click  undefined
# 26296945  22100221145014656   1604       5487952      checkpoint      basic
#
# ...

# %%
test = data

# %%
test['session_id'][:50]
# Out:
# 0     20090312431273200
# 1     20090312431273200
# 2     20090312431273200
# 3     20090312431273200
# 4     20090312431273200
# 5     20090312431273200
# 6     20090312431273200
# 7     20090312431273200
# 8     20090312431273200
# 9     20090312431273200
# 10    20090312431273200
# 11    20090312431273200
# 12    20090312431273200
# 13    20090312431273200
# 14    20090312431273200
# 15    20090312431273200
# 16    20090312431273200
# 17    20090312431273200
# 18    20090312431273200
# 19    20090312431273200
# 20    20090312431273200
# 21    20090312431273200
# 22    20090312431273200
# 23    20090312431273200
# 24    20090312431273200
# 25    20090312431273200
# 26    20090312431273200
# 27    20090312431273200
# 28    20090312431273200
# 29    20090312431273200
# 30    20090312431273200
# 31    20090312431273200
# 32    20090312431273200
# 33    20090312431273200
# 34    20090312431273200
# 35    20090312431273200
# 36    20090312431273200
# 37    20090312431273200
# ...
