# %%
import pandas as pd
from itertools import chain, combinations
from collections import defaultdict
import os
import csv
import ast
import sys

# %%
# Step 1: Reading and Processing CSV Files one at a time
def read_transactions(csv_folder):
    for filename in os.listdir(csv_folder):
        if filename.endswith('.csv'):
            with open(f"{csv_folder}/{filename}") as file:
                csvreader = csv.reader(file)
                csv.field_size_limit(1000000)
                transactions = [ast.literal_eval(row[0]) for row in csvreader]
                yield transactions

# %%
def collect_all_unique_items(csv_folder):
    unique_items = set()
    for transactions in read_transactions(csv_folder):
        for transaction in transactions:
            unique_items.update(transaction)
    return unique_items

# %%
# Step 2: Candidate Generation
def generate_candidate_itemsets(unique_items):
    return set([(item,) for item in unique_items])

def generate_candidate_itemsets_from_previous(frequent_itemsets, size):
    all_items = set()
    for itemset in frequent_itemsets:
        all_items.update(itemset)
    return set(combinations(all_items, size))

# Step 3: Support Calculation
def calculate_support(transactions, candidates):
    candidate_counts = defaultdict(int)
    for transaction in transactions:
        for candidate in candidates:
            if set(candidate).issubset(transaction):
                candidate_counts[candidate] += 1
    return candidate_counts

# Step 4: Pruning Candidates
def prune_candidates(candidate_counts, total_transactions, min_support):
    pruned_itemsets = {}
    for candidate, count in candidate_counts.items():
        support = count / total_transactions
        if support >= min_support:
            pruned_itemsets[candidate] = support

    return pruned_itemsets

# Step 5: Saving the Frequent Itemsets
def save_frequent_itemsets_csv(frequent_itemsets, output_file):
    # Convert the frequent itemsets dictionary into a list of tuples
    itemsets_list = [(list(itemset), support) for itemset, support in frequent_itemsets.items()]

    # Create a DataFrame from this list
    itemsets_df = pd.DataFrame(itemsets_list, columns=['Itemset', 'Support'])

    # Save the DataFrame to a CSV file
    itemsets_df.to_csv(output_file, index=False)

# %%
# Main Apriori Function
def apriori(csv_folder, max_length, min_support, output_file):
    all_unique_items = collect_all_unique_items(csv_folder)
    print(f'Unique Items: {all_unique_items}')
    all_frequent_itemsets = {}

    for k in range(1, max_length + 1):
        
        print(f"== Generating {k} Itemsets ==")
        if k == 1:
            candidate_itemsets = generate_candidate_itemsets(all_unique_items)
        else:
            candidate_itemsets = generate_candidate_itemsets_from_previous(all_frequent_itemsets, k)
        print(f'Candidate Itemsets for k={k}: {candidate_itemsets}')
        print(f"== {k} Frequent Itemsets generated ==")

        candidate_counts = defaultdict(int)
        total_transactions = 0

        print(f"== Calculating support for k={k} ==")
        for transactions in read_transactions(csv_folder):
            local_counts = calculate_support(transactions, candidate_itemsets)  
            for candidate, count in local_counts.items():
                candidate_counts[candidate] += count
            total_transactions += len(transactions)

        # Calculate global support and prune
        frequent_itemsets =  prune_candidates(candidate_counts, total_transactions, min_support)

        print(f"== Calculated support ==")
        
        if not frequent_itemsets:
            break

        all_frequent_itemsets.update(frequent_itemsets)
        print(f"== Finished {k} Frequent Itemsets ==")

    save_frequent_itemsets_csv(all_frequent_itemsets, output_file)
    return all_frequent_itemsets

# Run the Apriori algorithm
max_length = 3
min_support = 0.01

final_frequent_itemsets = apriori(
    csv_folder='../Dataset/transactions_split_chunks/', #EDIT THIS TO YOUR CHUNK FOLDER
    max_length=max_length, 
    min_support=min_support, 
    output_file=f'../Frequent Itemsets/transactions_{min_support}_{max_length}.csv',
)
print("Done")
# Out:
# Unique Items: {'Bills and Utilities', 'Tax', 'Health', 'Housing', 'Motor/Travel', 'Savings', 'Fines', 'Education', 'Groceries', 'Entertainment', 'Clothing', 'Gambling'}
# == Generating 1 Itemsets ==
# Candidate Itemsets for k=1: {('Health',), ('Gambling',), ('Fines',), ('Entertainment',), ('Housing',), ('Clothing',), ('Education',), ('Bills and Utilities',), ('Groceries',), ('Motor/Travel',), ('Tax',), ('Savings',)}
# == 1 Frequent Itemsets generated ==
# == Calculating support for k=1 ==
# == Calculated support ==
# == Finished 1 Frequent Itemsets ==
# == Generating 2 Itemsets ==
# Candidate Itemsets for k=2: {('Bills and Utilities', 'Housing'), ('Entertainment', 'Clothing'), ('Bills and Utilities', 'Clothing'), ('Health', 'Entertainment'), ('Housing', 'Clothing'), ('Savings', 'Entertainment'), ('Health', 'Groceries'), ('Groceries', 'Gambling'), ('Health', 'Savings'), ('Savings', 'Groceries'), ('Health', 'Gambling'), ('Bills and Utilities', 'Health'), ('Fines', 'Entertainment'), ('Education', 'Entertainment'), ('Savings', 'Gambling'), ('Bills and Utilities', 'Entertainment'), ('Fines', 'Groceries'), ('Health', 'Education'), ('Motor/Travel', 'Entertainment'), ('Housing', 'Entertainment'), ('Savings', 'Education'), ('Tax', 'Motor/Travel'), ('Bills and Utilities', 'Savings'), ('Motor/Travel', 'Groceries'), ('Education', 'Groceries'), ('Motor/Travel', 'Savings'), ('Bills and Utilities', 'Groceries'), ('Entertainment', 'Groceries'), ('Housing', 'Savings'), ('Tax', 'Fines'), ('Bills and Utilities', 'Tax'), ('Tax', 'Housing'), ('Housing', 'Groceries'), ('Tax', 'Clothing'), ('Fines', 'Gambling'), ('Education', 'Gambling'), ('Entertainment', 'Gambling'), ('Motor/Travel', 'Gambling'), ('Fines', 'Education'), ('Bills and Utilities', 'Gambling'), ('Motor/Travel', 'Education'), ('Housing', 'Gambling'), ('Bills and Utilities', 'Education'), ('Housing', 'Education'), ('Tax', 'Health'), ('Groceries', 'Clothing'), ('Health', 'Motor/Travel'), ('Tax', 'Entertainment'), ('Health', 'Fines'), ('Tax', 'Groceries'), ('Health', 'Housing'), ('Tax', 'Savings'), ('Health', 'Clothing'), ('Savings', 'Fines'), ('Savings', 'Clothing'), ('Clothing', 'Gambling'), ('Tax', 'Gambling'), ('Bills and Utilities', 'Motor/Travel'), ('Tax', 'Education'), ('Housing', 'Motor/Travel'), ('Fines', 'Clothing'), ('Bills and Utilities', 'Fines'), ('Motor/Travel', 'Fines'), ('Education', 'Clothing'), ('Housing', 'Fines'), ('Motor/Travel', 'Clothing')}
# == 2 Frequent Itemsets generated ==
# == Calculating support for k=2 ==
# == Calculated support ==
# == Finished 2 Frequent Itemsets ==
# == Generating 3 Itemsets ==
# Candidate Itemsets for k=3: {('Housing', 'Savings', 'Gambling'), ('Tax', 'Housing', 'Gambling'), ('Bills and Utilities', 'Motor/Travel', 'Fines'), ('Bills and Utilities', 'Education', 'Clothing'), ('Housing', 'Motor/Travel', 'Entertainment'), ('Bills and Utilities', 'Motor/Travel', 'Clothing'), ('Motor/Travel', 'Savings', 'Groceries'), ('Bills and Utilities', 'Groceries', 'Gambling'), ('Housing', 'Motor/Travel', 'Savings'), ('Bills and Utilities', 'Fines', 'Clothing'), ('Housing', 'Fines', 'Entertainment'), ('Motor/Travel', 'Entertainment', 'Groceries'), ('Bills and Utilities', 'Health', 'Groceries'), ('Tax', 'Groceries', 'Clothing'), ('Motor/Travel', 'Education', 'Entertainment'), ('Housing', 'Education', 'Gambling'), ('Housing', 'Motor/Travel', 'Gambling'), ('Motor/Travel', 'Groceries', 'Gambling'), ('Tax', 'Health', 'Motor/Travel'), ('Health', 'Savings', 'Fines'), ('Bills and Utilities', 'Savings', 'Entertainment'), ('Housing', 'Fines', 'Gambling'), ('Health', 'Savings', 'Clothing'), ('Fines', 'Education', 'Groceries'), ('Education', 'Entertainment', 'Groceries'), ('Bills and Utilities', 'Housing', 'Entertainment'), ('Bills and Utilities', 'Education', 'Groceries'), ('Bills and Utilities', 'Motor/Travel', 'Groceries'), ('Tax', 'Clothing', 'Gambling'), ('Motor/Travel', 'Fines', 'Education'), ('Tax', 'Motor/Travel', 'Clothing'), ('Bills and Utilities', 'Housing', 'Savings'), ('Bills and Utilities', 'Tax', 'Fines'), ('Bills and Utilities', 'Savings', 'Gambling'), ('Bills and Utilities', 'Fines', 'Groceries'), ('Health', 'Motor/Travel', 'Fines'), ('Bills and Utilities', 'Tax', 'Clothing'), ('Bills and Utilities', 'Entertainment', 'Gambling'), ('Groceries', 'Clothing', 'Gambling'), ('Bills and Utilities', 'Housing', 'Gambling'), ('Housing', 'Savings', 'Fines'), ('Tax', 'Housing', 'Fines'), ('Tax', 'Savings', 'Groceries'), ('Housing', 'Savings', 'Clothing'), ('Tax', 'Housing', 'Clothing'), ('Tax', 'Education', 'Entertainment'), ('Savings', 'Clothing', 'Gambling'), ('Bills and Utilities', 'Tax', 'Health'), ('Tax', 'Savings', 'Education'), ('Bills and Utilities', 'Health', 'Motor/Travel'), ('Health', 'Groceries', 'Gambling'), ('Tax', 'Motor/Travel', 'Groceries'), ('Housing', 'Motor/Travel', 'Fines'), ('Housing', 'Motor/Travel', 'Clothing'), ('Housing', 'Education', 'Clothing'), ('Motor/Travel', 'Groceries', 'Clothing'), ('Tax', 'Education', 'Gambling'), ('Bills and Utilities', 'Tax', 'Groceries'), ('Health', 'Fines', 'Groceries'), ('Fines', 'Clothing', 'Gambling'), ('Tax', 'Health', 'Education'), ('Tax', 'Entertainment', 'Gambling'), ('Housing', 'Fines', 'Clothing'), ('Housing', 'Savings', 'Groceries'), ('Bills and Utilities', 'Clothing', 'Gambling'), ('Savings', 'Groceries', 'Gambling'), ('Health', 'Fines', 'Education'), ('Bills and Utilities', 'Savings', 'Fines'), ('Health', 'Housing', 'Entertainment'), ('Bills and Utilities', 'Savings', 'Clothing'), ('Health', 'Motor/Travel', 'Gambling'), ('Bills and Utilities', 'Entertainment', 'Clothing'), ('Bills and Utilities', 'Housing', 'Fines'), ('Health', 'Housing', 'Savings'), ('Housing', 'Education', 'Groceries'), ('Housing', 'Motor/Travel', 'Groceries'), ('Savings', 'Fines', 'Education'), ('Motor/Travel', 'Fines', 'Entertainment'), ('Health', 'Housing', 'Gambling'), ('Housing', 'Fines', 'Groceries'), ('Housing', 'Entertainment', 'Gambling'), ('Fines', 'Entertainment', 'Gambling'), ('Motor/Travel', 'Savings', 'Education'), ('Health', 'Groceries', 'Clothing'), ('Tax', 'Health', 'Housing'), ('Bills and Utilities', 'Savings', 'Groceries'), ('Bills and Utilities', 'Health', 'Education'), ('Tax', 'Education', 'Clothing'), ('Entertainment', 'Clothing', 'Gambling'), ('Bills and Utilities', 'Tax', 'Motor/Travel'), ('Tax', 'Entertainment', 'Clothing'), ('Motor/Travel', 'Education', 'Gambling'), ('Savings', 'Groceries', 'Clothing'), ('Tax', 'Housing', 'Motor/Travel'), ('Health', 'Clothing', 'Gambling'), ('Tax', 'Health', 'Entertainment'), ('Health', 'Motor/Travel', 'Clothing'), ('Bills and Utili ...
# == 3 Frequent Itemsets generated ==
# == Calculating support for k=3 ==
# == Calculated support ==
# == Finished 3 Frequent Itemsets ==
# Done
