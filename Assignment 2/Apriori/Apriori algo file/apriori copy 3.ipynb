# %%
import pandas as pd
from itertools import chain, combinations
from collections import defaultdict
import os
import csv
import ast
import sys

# %%
# Step 1: Reading and Processing CSV Files one at a time
def read_transactions(csv_folder):
    for filename in os.listdir(csv_folder):
        if filename.endswith('.csv'):
            with open(f"{csv_folder}/{filename}") as file:
                csvreader = csv.reader(file)
                csv.field_size_limit(1000000)
                transactions = [ast.literal_eval(row[0]) for row in csvreader]
                yield transactions

# %%
def collect_all_unique_items(csv_folder):
    unique_items = set()
    for transactions in read_transactions(csv_folder):
        for transaction in transactions:
            unique_items.update(transaction)
    return unique_items

# %%
# Step 2: Candidate Generation
def generate_candidate_itemsets(unique_items):
    return set([(item,) for item in unique_items])

def generate_candidate_itemsets_from_previous(frequent_itemsets, size):
    all_items = set()
    for itemset in frequent_itemsets:
        all_items.update(itemset)
    return set(combinations(all_items, size))

# Step 3: Support Calculation
def calculate_support(transactions, candidates):
    candidate_counts = defaultdict(int)
    for transaction in transactions:
        for candidate in candidates:
            if set(candidate).issubset(transaction):
                candidate_counts[candidate] += 1
    return candidate_counts

# Step 4: Pruning Candidates
def prune_candidates(candidate_counts, total_transactions, min_support):
    pruned_itemsets = {}
    for candidate, count in candidate_counts.items():
        support = count / total_transactions
        if support >= min_support:
            pruned_itemsets[candidate] = support

    return pruned_itemsets

# Step 5: Saving the Frequent Itemsets
def save_frequent_itemsets_csv(frequent_itemsets, output_file):
    # Convert the frequent itemsets dictionary into a list of tuples
    itemsets_list = [(list(itemset), support) for itemset, support in frequent_itemsets.items()]

    # Create a DataFrame from this list
    itemsets_df = pd.DataFrame(itemsets_list, columns=['Itemset', 'Support'])

    # Save the DataFrame to a CSV file
    itemsets_df.to_csv(output_file, index=False)

# %%
# Main Apriori Function
def apriori(csv_folder, max_length, min_support, output_file):
    all_unique_items = collect_all_unique_items(csv_folder)
    print(f'Unique Items: {all_unique_items}')
    all_frequent_itemsets = {}

    for k in range(1, max_length + 1):
        
        print(f"== Generating {k} Itemsets ==")
        if k == 1:
            candidate_itemsets = generate_candidate_itemsets(all_unique_items)
        else:
            candidate_itemsets = generate_candidate_itemsets_from_previous(all_frequent_itemsets, k)
        print(f'Candidate Itemsets for k={k}: {candidate_itemsets}')
        print(f"== {k} Frequent Itemsets generated ==")

        candidate_counts = defaultdict(int)
        total_transactions = 0

        print(f"== Calculating support for k={k} ==")
        for transactions in read_transactions(csv_folder):
            local_counts = calculate_support(transactions, candidate_itemsets)  
            for candidate, count in local_counts.items():
                candidate_counts[candidate] += count
            total_transactions += len(transactions)

        # Calculate global support and prune
        frequent_itemsets =  prune_candidates(candidate_counts, total_transactions, min_support)

        print(f"== Calculated supported ==")
        if not frequent_itemsets:
            break

        all_frequent_itemsets.update(frequent_itemsets)
        print(f"== Finished {k} Frequent Itemsets ==")

    save_frequent_itemsets_csv(all_frequent_itemsets, output_file)
    return all_frequent_itemsets

# Run the Apriori algorithm
max_length = 3
min_support = 0.01

final_frequent_itemsets = apriori(
    csv_folder='../Dataset/job_title_split_chunks/', #EDIT THIS TO YOUR CHUNK FOLDER
    max_length=max_length, 
    min_support=min_support, 
    output_file=f'../Frequent Itemsets/job_title_{min_support}_{max_length}.csv',
)
print("Done")
# Out:
# Unique Items: {'practitioner', 'java', 'researcher', 'litigation', 'process', 'human', 'it', 'registered', 'finance', 'business', 'procurement', 'coordinator', 'environmental', 'consultant', 'occupational', 'nurse', 'ambassador', 'architectural', 'software', 'event', 'graphic', 'associate', 'architect', 'media', 'sales', 'representative', 'executive', 'legal', 'market', 'pharmaceutical', 'development', 'quality', 'email', 'success', 'writer', 'support', 'web', 'content', 'digital', 'teacher', 'social', 'financial', 'data', 'dental', 'copywriter', 'service', 'brand', 'developer', 'tax', 'tester', 'back-end', 'counselor', 'administrative', 'physical', 'interior', 'customer', 'hygienist', 'ui', 'planner', 'mechanical', 'worker', 'systems', 'civil', 'database', 'resources', 'secretary', 'landscape', 'generalist', 'family', 'security', 'supply', 'investment', 'specialist', 'operations', 'network', 'public', 'electrical', 'speech', 'advisor', 'office', 'hr', 'chain', 'entry', 'counsel', 'banker', 'sem', 'inventory', 'personal', 'agent', 'psychologist', 'assurance', 'marketing', 'director', 'ux', 'substance', 'analyst', 'accountant', 'lawyer', 'physician', 'administrator', 'attorney', 'technical', 'abuse', 'designer', 'controller', 'product', 'chemical', 'assistant', 'key', 'relations', 'art', 'scientist', 'engineer', 'veterinarian', 'purchasing', 'manager', 'account', 'seo', 'qa', 'front-end', 'research', 'urban', 'technician', 'therapist', 'paralegal', 'pediatrician', 'aerospace', 'wedding', 'project', 'clerk', 'structural', 'ux/ui'}
# == Generating 1 Itemsets ==
# Candidate Itemsets for k=1: {('family',), ('java',), ('analyst',), ('ambassador',), ('brand',), ('it',), ('technical',), ('consultant',), ('network',), ('qa',), ('civil',), ('sales',), ('research',), ('clerk',), ('digital',), ('web',), ('representative',), ('front-end',), ('environmental',), ('back-end',), ('customer',), ('abuse',), ('art',), ('development',), ('administrative',), ('investment',), ('attorney',), ('marketing',), ('human',), ('seo',), ('public',), ('specialist',), ('architect',), ('legal',), ('banker',), ('success',), ('engineer',), ('urban',), ('controller',), ('market',), ('chain',), ('supply',), ('therapist',), ('paralegal',), ('mechanical',), ('pediatrician',), ('scientist',), ('executive',), ('product',), ('sem',), ('registered',), ('planner',), ('tester',), ('security',), ('technician',), ('tax',), ('designer',), ('pharmaceutical',), ('copywriter',), ('ui',), ('litigation',), ('relations',), ('finance',), ('content',), ('secretary',), ('advisor',), ('support',), ('assurance',), ('social',), ('service',), ('practitioner',), ('speech',), ('architectural',), ('project',), ('associate',), ('hygienist',), ('electrical',), ('veterinarian',), ('director',), ('counselor',), ('procurement',), ('hr',), ('business',), ('wedding',), ('nurse',), ('data',), ('graphic',), ('worker',), ('landscape',), ('chemical',), ('financial',), ('accountant',), ('occupational',), ('manager',), ('account',), ('researcher',), ('substance',), ('event',), ('entry',), ('quality',), ('physical',), ('lawyer',), ('structural',), ('administrator',), ('coordinator',), ('assistant',), ('counsel',), ('interior',), ('media',), ('database',), ('personal',), ('aerospace',), ('inventory',), ('resources',), ('ux',), ('email',), ('generalist',), ('agent',), ('purchasing',), ('key',), ('writer',), ('developer',), ('process',), ('software',), ('systems',), ('physician',), ('operations',), ('ux/ui',), ('teacher',), ('office',), ('psychologist',), ('dental',)}
# == 1 Frequent Itemsets generated ==
# == Calculating support for k=1 ==
# == Calculated supported ==
# == Finished 1 Frequent Itemsets ==
# == Generating 2 Itemsets ==
# Candidate Itemsets for k=2: {('chain', 'legal'), ('coordinator', 'database'), ('project', 'administrator'), ('executive', 'it'), ('environmental', 'analyst'), ('financial', 'seo'), ('practitioner', 'advisor'), ('chain', 'ux/ui'), ('engineer', 'sales'), ('specialist', 'teacher'), ('financial', 'engineer'), ('designer', 'data'), ('brand', 'research'), ('coordinator', 'administrative'), ('writer', 'legal'), ('practitioner', 'social'), ('marketing', 'legal'), ('writer', 'developer'), ('chemical', 'developer'), ('planner', 'analyst'), ('writer', 'ux/ui'), ('business', 'environmental'), ('practitioner', 'media'), ('environmental', 'customer'), ('marketing', 'ux/ui'), ('marketing', 'family'), ('chemical', 'family'), ('engineer', 'legal'), ('business', 'seo'), ('data', 'business'), ('coordinator', 'consultant'), ('it', 'legal'), ('business', 'engineer'), ('account', 'sales'), ('tester', 'planner'), ('it', 'ux/ui'), ('service', 'environmental'), ('software', 'landscape'), ('service', 'seo'), ('hr', 'chain'), ('director', 'administrator'), ('assistant', 'customer'), ('tester', 'marketing'), ('assistant', 'advisor'), ('account', 'legal'), ('administrative', 'supply'), ('account', 'ux/ui'), ('procurement', 'advisor'), ('advisor', 'developer'), ('financial', 'landscape'), ('practitioner', 'agent'), ('advisor', 'ux/ui'), ('electrical', 'scientist'), ('service', 'nurse'), ('purchasing', 'legal'), ('social', 'environmental'), ('advisor', 'family'), ('electrical', 'planner'), ('manager', 'administrator'), ('media', 'family'), ('purchasing', 'ux/ui'), ('scientist', 'director'), ('social', 'seo'), ('support', 'manager'), ('web', 'scientist'), ('mechanical', 'landscape'), ('web', 'planner'), ('customer', 'investment'), ('designer', 'environmental'), ('social', 'engineer'), ('customer', 'marketing'), ('electrical', 'investment'), ('business', 'landscape'), ('electrical', 'marketing'), ('representative', 'legal'), ('event', 'administrator'), ('financial', 'database'), ('network', 'supply'), ('art', 'investment'), ('representative', 'ux/ui'), ('designer', 'engineer'), ('customer', 'mechanical'), ('web', 'marketing'), ('practitioner', 'representative'), ('practitioner', 'front-end'), ('writer', 'director'), ('specialist', 'financial'), ('network', 'hr'), ('electrical', 'mechanical'), ('writer', 'procurement'), ('marketing', 'director'), ('writer', 'business'), ('executive', 'administrator'), ('chemical', 'director'), ('specialist', 'developer'), ('nurse', 'supply'), ('data', 'advisor'), ('service', 'landscape'), ('mechanical', 'database'), ('art', 'mechanical'), ('brand', 'coordinator'), ('executive', 'digital'), ('manager', 'research'), ('specialist', 'family'), ('consultant', 'family'), ('assistant', 'agent'), ('business', 'database'), ('teacher', 'investment'), ('network', 'account'), ('environmental', 'front-end'), ('it', 'procurement'), ('procurement', 'agent'), ('financial', 'consultant'), ('it', 'business'), ('developer', 'supply'), ('seo', 'planner'), ('executive', 'writer'), ('coordinator', 'family'), ('sales', 'ux/ui'), ('developer', 'hr'), ('teacher', 'mechanical'), ('network', 'media'), ('environmental', 'software'), ('digital', 'supply'), ('sales', 'family'), ('service', 'database'), ('brand', 'engineer'), ('agent', 'legal'), ('designer', 'chain'), ('social', 'landscape'), ('administrative', 'agent'), ('digital', 'hr'), ('seo', 'investment'), ('agent', 'ux/ui'), ('seo', 'marketing'), ('legal', 'investment'), ('nurse', 'media'), ('executive', 'research'), ('hr', 'systems'), ('business', 'consultant'), ('family', 'supply'), ('service', 'administrative'), ('support', 'art'), ('electrical', 'data'), ('assistant', 'representative'), ('assistant', 'front-end'), ('advisor', 'director'), ('manager', 'tester'), ('planner', 'software'), ('systems', 'ux/ui'), ('procurement', 'representative'), ('procurement', 'front-end'), ('specialist', 'network'), ('seo', 'mechanical'), ('digital', 'account'), ('systems', 'family'), ('hr', 'sales'), ('developer', ...
# == 2 Frequent Itemsets generated ==
# == Calculating support for k=2 ==
# == Calculated supported ==
# == Finished 2 Frequent Itemsets ==
# == Generating 3 Itemsets ==
# Candidate Itemsets for k=3: {('seo', 'software', 'legal'), ('specialist', 'scientist', 'account'), ('account', 'research', 'family'), ('account', 'manager', 'marketing'), ('web', 'engineer', 'planner'), ('designer', 'scientist', 'account'), ('practitioner', 'customer', 'planner'), ('assistant', 'analyst', 'administrator'), ('advisor', 'manager', 'nurse'), ('data', 'consultant', 'mechanical'), ('teacher', 'art', 'planner'), ('web', 'customer', 'legal'), ('director', 'project', 'administrator'), ('engineer', 'landscape', 'supply'), ('specialist', 'electrical', 'tester'), ('procurement', 'art', 'agent'), ('chain', 'agent', 'mechanical'), ('procurement', 'advisor', 'front-end'), ('network', 'marketing', 'family'), ('designer', 'electrical', 'tester'), ('data', 'scientist', 'seo'), ('network', 'engineer', 'investment'), ('nurse', 'customer', 'sales'), ('purchasing', 'marketing', 'landscape'), ('social', 'developer', 'hr'), ('writer', 'purchasing', 'administrative'), ('web', 'chemical', 'mechanical'), ('procurement', 'agent', 'investment'), ('advisor', 'hr', 'manager'), ('web', 'it', 'marketing'), ('business', 'therapist', 'analyst'), ('network', 'web', 'financial'), ('environmental', 'database', 'director'), ('practitioner', 'financial', 'database'), ('writer', 'ux/ui', 'legal'), ('agent', 'ux/ui', 'legal'), ('writer', 'digital', 'sales'), ('support', 'brand', 'consultant'), ('practitioner', 'representative', 'ux/ui'), ('web', 'social', 'customer'), ('support', 'scientist', 'consultant'), ('financial', 'marketing', 'legal'), ('financial', 'media', 'supply'), ('purchasing', 'seo', 'analyst'), ('practitioner', 'designer', 'engineer'), ('writer', 'data', 'account'), ('executive', 'writer', 'mechanical'), ('web', 'advisor', 'planner'), ('electrical', 'chemical', 'software'), ('web', 'business', 'nurse'), ('customer', 'planner', 'ux/ui'), ('network', 'scientist', 'tester'), ('service', 'mechanical', 'database'), ('scientist', 'brand', 'nurse'), ('research', 'media', 'supply'), ('customer', 'mechanical', 'investment'), ('customer', 'planner', 'family'), ('financial', 'business', 'seo'), ('scientist', 'developer', 'analyst'), ('designer', 'it', 'account'), ('digital', 'chemical', 'hr'), ('electrical', 'manager', 'investment'), ('assistant', 'seo', 'representative'), ('coordinator', 'systems', 'marketing'), ('coordinator', 'tester', 'nurse'), ('web', 'data', 'it'), ('systems', 'family', 'legal'), ('brand', 'manager', 'mechanical'), ('electrical', 'teacher', 'scientist'), ('specialist', 'network', 'event'), ('data', 'seo', 'director'), ('mechanical', 'systems', 'landscape'), ('electrical', 'financial', 'administrative'), ('web', 'procurement', 'event'), ('designer', 'network', 'event'), ('advisor', 'scientist', 'coordinator'), ('support', 'teacher', 'nurse'), ('support', 'marketing', 'representative'), ('designer', 'consultant', 'research'), ('data', 'it', 'seo'), ('digital', 'data', 'ux/ui'), ('social', 'engineer', 'supply'), ('designer', 'scientist', 'agent'), ('electrical', 'art', 'mechanical'), ('support', 'data', 'chemical'), ('writer', 'family', 'ux/ui'), ('it', 'consultant', 'ux/ui'), ('executive', 'database', 'administrator'), ('electrical', 'consultant', 'ux/ui'), ('teacher', 'coordinator', 'mechanical'), ('social', 'data', 'architect'), ('it', 'marketing', 'landscape'), ('nurse', 'director', 'architect'), ('teacher', 'business', 'supply'), ('service', 'art', 'architect'), ('network', 'procurement', 'chain'), ('environmental', 'supply', 'legal'), ('support', 'social', 'ux/ui'), ('consultant', 'nurse', 'marketing'), ('art', 'systems', 'administrator'), ('systems', 'director', 'analyst'), ('database', 'project', 'supply'), ('support', 'social', 'family'), ('service', 'seo', 'marketing'), ('nurse', 'agent', 'sales'), ('support', 'therapist', 'ux/ui'), ('service', 'business', 'consultant'), ('financial', 'assistant', 'art'), ('coordinator', 'project', 'ux/ui'), ('teacher', 'chain', 'supply'), ('it', 'seo', 'analyst'), ('art', 'scientis ...
# == 3 Frequent Itemsets generated ==
# == Calculating support for k=3 ==
# == Calculated supported ==
# == Finished 3 Frequent Itemsets ==
# Done
